# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Chargement des données**

# %%
df = pd.read_csv('/content/Retail_Transactions_Dataset.csv')
df.head(20)
# Out:
#     Transaction_ID                 Date      Customer_Name  \
# 0       1000000000  2022-01-21 06:27:29       Stacey Price
# 1       1000000001  2023-03-01 13:01:21   Michelle Carlson
# 2       1000000002  2024-03-21 15:37:04        Lisa Graves
# 3       1000000003  2020-10-31 09:59:47  Mrs. Patricia May
# 4       1000000004  2020-12-10 00:59:59     Susan Mitchell
# 5       1000000005  2021-10-07 12:37:26     Joshua Frazier
# 6       1000000006  2023-01-08 10:40:03   Victoria Garrett
# 7       1000000007  2020-09-03 12:39:59      Sydney Waller
# 8       1000000008  2021-04-05 06:32:18    Kimberly Morgan
# 9       1000000009  2021-07-08 10:08:59        Lori Conway
# 10      1000000010  2020-03-18 18:58:18    Randall Roberts
# 11      1000000011  2023-03-30 19:26:41     Jeremiah White
# 12      1000000012  2023-05-27 15:52:59       Sheila Mcgee
# 13      1000000013  2023-04-02 09:24:11        Allen Miles
# 14      1000000014  2020-04-09 04:31:05        Mark Howard
# ...

# %% [markdown]
# # **Traitement des données**

# %%
df.duplicated().sum()
df.isnull()
valeurs_nulles = df.isnull().sum()
print(valeurs_nulles)
# Out:
# Transaction_ID          0
# Date                    0
# Customer_Name           0
# Product                 0
# Total_Items             0
# Total_Cost              0
# Payment_Method          0
# City                    0
# Store_Type              0
# Discount_Applied        1
# Customer_Category       1
# Season                  1
# Promotion            8227
# dtype: int64

# %%
df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_Name', 'Product', 'Total_Items',
#        'Total_Cost', 'Payment_Method', 'City', 'Store_Type',
#        'Discount_Applied', 'Customer_Category', 'Season', 'Promotion'],
#       dtype='object')

# %%
df['Customer_Name'].unique()
# Out:
# array(['Stacey Price', 'Michelle Carlson', 'Lisa Graves', ...,
#        'Mr. Juan Thompson', 'Gregory Jordan', 'David Hayden'],
#       dtype=object)

# %%
# Dupliquer le DataFrame
df_duplicate = df.copy()

# %% [markdown]
# # **Séparation des listes de produits en ligne**

# %%
# 1. Séparation des produits : chaque produit sera sur une ligne distincte
from itertools import chain

df['Product'] = df['Product'].str.strip('[]').str.replace("'", "").str.split(',')
df = df.explode('Product')

# %%
df
# Out:
#        Transaction_ID                 Date     Customer_Name  \
# 0          1000000000  2022-01-21 06:27:29      Stacey Price
# 0          1000000000  2022-01-21 06:27:29      Stacey Price
# 0          1000000000  2022-01-21 06:27:29      Stacey Price
# 1          1000000001  2023-03-01 13:01:21  Michelle Carlson
# 1          1000000001  2023-03-01 13:01:21  Michelle Carlson
# ...               ...                  ...               ...
# 24735      1000024735  2022-12-24 14:06:08      David Hayden
# 24735      1000024735  2022-12-24 14:06:08      David Hayden
# 24735      1000024735  2022-12-24 14:06:08      David Hayden
# 24735      1000024735  2022-12-24 14:06:08      David Hayden
# 24735      1000024735  2022-12-24 14:06:08      David Hayden
#
#                   Product  Total_Items  Total_Cost  Payment_Method  \
# 0                 Ketchup            3       71.65  Mobile Payment
# 0           Shaving Cream            3       71.65  Mobile Payment
# ...

# %%
# Ajouter la colonne Id
df = df.assign(Id=range(1, len(df) + 1))

# %%
df
# Out:
#        Transaction_ID                 Date     Customer_Name  \
# 0          1000000000  2022-01-21 06:27:29      Stacey Price
# 0          1000000000  2022-01-21 06:27:29      Stacey Price
# 0          1000000000  2022-01-21 06:27:29      Stacey Price
# 1          1000000001  2023-03-01 13:01:21  Michelle Carlson
# 1          1000000001  2023-03-01 13:01:21  Michelle Carlson
# ...               ...                  ...               ...
# 24735      1000024735  2022-12-24 14:06:08      David Hayden
# 24735      1000024735  2022-12-24 14:06:08      David Hayden
# 24735      1000024735  2022-12-24 14:06:08      David Hayden
# 24735      1000024735  2022-12-24 14:06:08      David Hayden
# 24735      1000024735  2022-12-24 14:06:08      David Hayden
#
#                   Product  Total_Items  Total_Cost  Payment_Method  \
# 0                 Ketchup            3       71.65  Mobile Payment
# 0           Shaving Cream            3       71.65  Mobile Payment
# ...

# %% [markdown]
# # **Traitement des dates**

# %%
# Transformer les dates
df['Date'] = pd.to_datetime(df['Date'])

# Remplacer les valeurs NaN dans la colonne Promotion par "No Promotion"
df['Promotion'].fillna('No Promotion', inplace=True)

# Afficher les types de données après transformationa
print(df.dtypes)
# Out:
# Transaction_ID                int64
# Date                 datetime64[ns]
# Customer_Name                object
# Product                      object
# Total_Items                   int64
# Total_Cost                  float64
# Payment_Method               object
# City                         object
# Store_Type                   object
# Discount_Applied             object
# Customer_Category            object
# Season                       object
# Promotion                    object
# Id                            int64
# dtype: object
# <ipython-input-12-2b7319da3435>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# 2. Transformation de la date
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['Season'] = df['Season'].astype('category')  # Saison catégorisée

# %%
# Affichage des colonnes spécifiques
result = df[['Date', 'Year', 'Month', 'Day', 'Season']]
print(result)
# Out:
#                      Date  Year  Month  Day  Season
# 0     2022-01-21 06:27:29  2022      1   21  Winter
# 0     2022-01-21 06:27:29  2022      1   21  Winter
# 0     2022-01-21 06:27:29  2022      1   21  Winter
# 1     2023-03-01 13:01:21  2023      3    1    Fall
# 1     2023-03-01 13:01:21  2023      3    1    Fall
# ...                   ...   ...    ...  ...     ...
# 24735 2022-12-24 14:06:08  2022     12   24     NaN
# 24735 2022-12-24 14:06:08  2022     12   24     NaN
# 24735 2022-12-24 14:06:08  2022     12   24     NaN
# 24735 2022-12-24 14:06:08  2022     12   24     NaN
# 24735 2022-12-24 14:06:08  2022     12   24     NaN
#
# [74163 rows x 5 columns]

# %%
df
# Out:
#        Transaction_ID                Date     Customer_Name  \
# 0          1000000000 2022-01-21 06:27:29      Stacey Price
# 0          1000000000 2022-01-21 06:27:29      Stacey Price
# 0          1000000000 2022-01-21 06:27:29      Stacey Price
# 1          1000000001 2023-03-01 13:01:21  Michelle Carlson
# 1          1000000001 2023-03-01 13:01:21  Michelle Carlson
# ...               ...                 ...               ...
# 24735      1000024735 2022-12-24 14:06:08      David Hayden
# 24735      1000024735 2022-12-24 14:06:08      David Hayden
# 24735      1000024735 2022-12-24 14:06:08      David Hayden
# 24735      1000024735 2022-12-24 14:06:08      David Hayden
# 24735      1000024735 2022-12-24 14:06:08      David Hayden
#
#                   Product  Total_Items  Total_Cost  Payment_Method  \
# 0                 Ketchup            3       71.65  Mobile Payment
# 0           Shaving Cream            3       71.65  Mobile Payment
# ...

# %% [markdown]
# # **Création des differentes tables**

# %%
Times = df[['Transaction_ID','Date', 'Year', 'Month', 'Day', 'Season',]].drop_duplicates().reset_index(drop=True)

# %%
Times = Times.rename(columns={'Transaction_ID': 'Times_ID'})

# %%
Times
# Out:
#          Times_ID                Date  Year  Month  Day  Season
# 0      1000000000 2022-01-21 06:27:29  2022      1   21  Winter
# 1      1000000001 2023-03-01 13:01:21  2023      3    1    Fall
# 2      1000000002 2024-03-21 15:37:04  2024      3   21  Winter
# 3      1000000003 2020-10-31 09:59:47  2020     10   31  Spring
# 4      1000000004 2020-12-10 00:59:59  2020     12   10  Winter
# ...           ...                 ...   ...    ...  ...     ...
# 24731  1000024731 2023-10-16 19:25:50  2023     10   16  Spring
# 24732  1000024732 2022-03-04 21:42:50  2022      3    4  Winter
# 24733  1000024733 2020-12-23 22:30:03  2020     12   23  Summer
# 24734  1000024734 2020-09-21 05:25:41  2020      9   21    Fall
# 24735  1000024735 2022-12-24 14:06:08  2022     12   24     NaN
#
# [24736 rows x 6 columns]

# %%
Customer = df[['Transaction_ID','Customer_Name', 'Customer_Category', 'City','Payment_Method']].drop_duplicates().reset_index(drop=True)

# %%
Customer = Customer.rename(columns={'Transaction_ID': 'Customer_ID'})

# %%
Customer.duplicated().sum()
# Out:
# 0

# %%
Customer
# Out:
#        Customer_ID      Customer_Name Customer_Category           City  \
# 0       1000000000       Stacey Price         Homemaker    Los Angeles
# 1       1000000001   Michelle Carlson      Professional  San Francisco
# 2       1000000002        Lisa Graves      Professional        Houston
# 3       1000000003  Mrs. Patricia May         Homemaker        Chicago
# 4       1000000004     Susan Mitchell       Young Adult        Houston
# ...            ...                ...               ...            ...
# 24731   1000024731  Mr. Juan Thompson      Professional  San Francisco
# 24732   1000024732     Gregory Jordan      Professional         Boston
# 24733   1000024733    Jennifer Turner          Teenager         Boston
# 24734   1000024734      Nicole Miller           Retiree        Chicago
# 24735   1000024735       David Hayden               NaN         Boston
#
#        Payment_Method
# 0      Mobile Payment
# 1                Cash
# 2         Credit Card
# ...

# %%
Produit = df[['Product']].drop_duplicates().reset_index(drop=True)

# %%
Produit.duplicated().sum()
# Out:
# 0

# %%
Produit=Produit.assign(Id_Produit=range(1, len(Produit) + 1))

# %%
Produit
# Out:
#             Product  Id_Produit
# 0           Ketchup           1
# 1     Shaving Cream           2
# 2       Light Bulbs           3
# 3         Ice Cream           4
# 4              Milk           5
# ..              ...         ...
# 157          Butter         158
# 158      Mayonnaise         159
# 159   Ironing Board         160
# 160    Toilet Paper         161
# 161             Jam         162
#
# [162 rows x 2 columns]

# %%
Magasin = df[['Store_Type', 'City']].drop_duplicates().reset_index(drop=True)

# %%
Magasin= Magasin.assign(Id_Magasin=range(1, len(Magasin) + 1))

# %%
Magasin
# Out:
#           Store_Type           City  Id_Magasin
# 0     Warehouse Club    Los Angeles           1
# 1    Specialty Store  San Francisco           2
# 2   Department Store        Houston           3
# 3           Pharmacy        Chicago           4
# 4    Specialty Store        Houston           5
# ..               ...            ...         ...
# 56    Warehouse Club        Chicago          57
# 57       Supermarket         Boston          58
# 58       Supermarket        Atlanta          59
# 59    Warehouse Club         Boston          60
# 60     Convenience S         Boston          61
#
# [61 rows x 3 columns]

# %%
Magasin['Produit_ID']=Produit['Id_Produit']

# %%
Magasin
# Out:
#           Store_Type           City  Id_Magasin  Produit_ID
# 0     Warehouse Club    Los Angeles           1           1
# 1    Specialty Store  San Francisco           2           2
# 2   Department Store        Houston           3           3
# 3           Pharmacy        Chicago           4           4
# 4    Specialty Store        Houston           5           5
# ..               ...            ...         ...         ...
# 56    Warehouse Club        Chicago          57          57
# 57       Supermarket         Boston          58          58
# 58       Supermarket        Atlanta          59          59
# 59    Warehouse Club         Boston          60          60
# 60     Convenience S         Boston          61          61
#
# [61 rows x 4 columns]

# %%
Promotion = df[['Promotion', 'Discount_Applied','Transaction_ID']].drop_duplicates().reset_index(drop=True)
Promotion=Promotion.assign(Id_Promotion=range(1, len(Promotion) + 1))

# %%
City = df[['City']].drop_duplicates().reset_index(drop=True)
City=City.assign(Id_City=range(1, len(City) + 1))

# %%
City
# Out:
#             City  Id_City
# 0    Los Angeles        1
# 1  San Francisco        2
# 2        Houston        3
# 3        Chicago        4
# 4         Boston        5
# 5       New York        6
# 6        Seattle        7
# 7          Miami        8
# 8         Dallas        9
# 9        Atlanta       10

# %%
Transaction_fact=df[['Transaction_ID', 'Total_Items','Total_Cost']].drop_duplicates().reset_index(drop=True)

# %%
Transaction_fact['Total_Cost'] = Transaction_fact['Total_Cost'].astype(int)

# %%
Transaction_fact
# Out:
#        Transaction_ID  Total_Items  Total_Cost
# 0          1000000000            3          71
# 1          1000000001            2          25
# 2          1000000002            6          41
# 3          1000000003            1          39
# 4          1000000004           10          16
# ...               ...          ...         ...
# 24731      1000024731            7          33
# 24732      1000024732            2          66
# 24733      1000024733            4          10
# 24734      1000024734            3          35
# 24735      1000024735            9           6
#
# [24736 rows x 3 columns]

# %%
Transaction_fact
# Out:
#        Transaction_ID  Total_Items  Total_Cost
# 0          1000000000            3          71
# 1          1000000001            2          25
# 2          1000000002            6          41
# 3          1000000003            1          39
# 4          1000000004           10          16
# ...               ...          ...         ...
# 24731      1000024731            7          33
# 24732      1000024732            2          66
# 24733      1000024733            4          10
# 24734      1000024734            3          35
# 24735      1000024735            9           6
#
# [24736 rows x 3 columns]

# %% [markdown]
# **Création de la table de Fait ( Transaction_Fact)**

# %%
Transaction_fact['Times_ID']=Times['Times_ID']
Transaction_fact['Customer_ID']=Customer['Customer_ID']
Transaction_fact['Produit_ID']=Produit['Id_Produit']
Transaction_fact['Magasin_ID']=Magasin['Id_Magasin']
Transaction_fact['Promotion_ID']=Promotion['Id_Promotion']

# %%
Transaction_fact
# Out:
#        Transaction_ID  Total_Items  Total_Cost    Times_ID  Customer_ID  \
# 0          1000000000            3          71  1000000000   1000000000
# 1          1000000001            2          25  1000000001   1000000001
# 2          1000000002            6          41  1000000002   1000000002
# 3          1000000003            1          39  1000000003   1000000003
# 4          1000000004           10          16  1000000004   1000000004
# ...               ...          ...         ...         ...          ...
# 24731      1000024731            7          33  1000024731   1000024731
# 24732      1000024732            2          66  1000024732   1000024732
# 24733      1000024733            4          10  1000024733   1000024733
# 24734      1000024734            3          35  1000024734   1000024734
# 24735      1000024735            9           6  1000024735   1000024735
#
#        Produit_ID  Magasin_ID  Promotion_ID
# 0             1.0         1.0             1
# ...

# %%
Transaction_fact
# Out:
#        Transaction_ID  Total_Items  Total_Cost    Times_ID  Customer_ID  \
# 0          1000000000            3          71  1000000000   1000000000
# 1          1000000001            2          25  1000000001   1000000001
# 2          1000000002            6          41  1000000002   1000000002
# 3          1000000003            1          39  1000000003   1000000003
# 4          1000000004           10          16  1000000004   1000000004
# ...               ...          ...         ...         ...          ...
# 24731      1000024731            7          33  1000024731   1000024731
# 24732      1000024732            2          66  1000024732   1000024732
# 24733      1000024733            4          10  1000024733   1000024733
# 24734      1000024734            3          35  1000024734   1000024734
# 24735      1000024735            9           6  1000024735   1000024735
#
#        Produit_ID  Magasin_ID  Promotion_ID
# 0             1.0         1.0             1
# ...

# %% [markdown]
# # **Visualisation des tables**

# %%
Times
# Out:
#          Times_ID                Date  Year  Month  Day  Season
# 0      1000000000 2022-01-21 06:27:29  2022      1   21  Winter
# 1      1000000001 2023-03-01 13:01:21  2023      3    1    Fall
# 2      1000000002 2024-03-21 15:37:04  2024      3   21  Winter
# 3      1000000003 2020-10-31 09:59:47  2020     10   31  Spring
# 4      1000000004 2020-12-10 00:59:59  2020     12   10  Winter
# ...           ...                 ...   ...    ...  ...     ...
# 24731  1000024731 2023-10-16 19:25:50  2023     10   16  Spring
# 24732  1000024732 2022-03-04 21:42:50  2022      3    4  Winter
# 24733  1000024733 2020-12-23 22:30:03  2020     12   23  Summer
# 24734  1000024734 2020-09-21 05:25:41  2020      9   21    Fall
# 24735  1000024735 2022-12-24 14:06:08  2022     12   24     NaN
#
# [24736 rows x 6 columns]

# %%
Customer
# Out:
#        Customer_ID      Customer_Name Customer_Category           City  \
# 0       1000000000       Stacey Price         Homemaker    Los Angeles
# 1       1000000001   Michelle Carlson      Professional  San Francisco
# 2       1000000002        Lisa Graves      Professional        Houston
# 3       1000000003  Mrs. Patricia May         Homemaker        Chicago
# 4       1000000004     Susan Mitchell       Young Adult        Houston
# ...            ...                ...               ...            ...
# 24731   1000024731  Mr. Juan Thompson      Professional  San Francisco
# 24732   1000024732     Gregory Jordan      Professional         Boston
# 24733   1000024733    Jennifer Turner          Teenager         Boston
# 24734   1000024734      Nicole Miller           Retiree        Chicago
# 24735   1000024735       David Hayden               NaN         Boston
#
#        Payment_Method
# 0      Mobile Payment
# 1                Cash
# 2         Credit Card
# ...

# %%
Produit
# Out:
#             Product  Id_Produit
# 0           Ketchup           1
# 1     Shaving Cream           2
# 2       Light Bulbs           3
# 3         Ice Cream           4
# 4              Milk           5
# ..              ...         ...
# 157          Butter         158
# 158      Mayonnaise         159
# 159   Ironing Board         160
# 160    Toilet Paper         161
# 161             Jam         162
#
# [162 rows x 2 columns]

# %% [markdown]
# # **Exportation des differentes Tables**

# %%
import pandas as pd
from google.colab import files

# Étape 2 : Enregistrement au format CSV
Transaction_fact.to_csv('Transaction_fact.csv', index=False)
Times.to_csv('Times.csv', index=False)
Magasin.to_csv('Magasin.csv', index=False)
Customer.to_csv('Customer.csv', index=False)
Produit.to_csv('Produit.csv', index=False)
Promotion.to_csv('Promotion.csv', index=False)
City.to_csv('City.csv', index=False)

# Étape 3 : Téléchargement des fichiers
files.download('Transaction_fact.csv')
files.download('Times.csv')
files.download('Magasin.csv')
files.download('Customer.csv')
files.download('Produit.csv')
files.download('Promotion.csv')
files.download('City.csv')
